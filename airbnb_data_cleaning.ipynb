# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import folium
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df  = pd.read_excel("../Project/Data_set/Airbnb_Open_Data.xlsx")

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %% [markdown]
# **Check Null Values**

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                 270
# host id                                0
# host_identity_verified               289
# host name                            408
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %% [markdown]
# **Handel Null Values By using Fill na & Drop na**

# %%
print(df.NAME.unique())
# Out:
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Elmhurst 1st Fl Rightl Bedroom'
#  'Elmhurst 1st Floor BR w/ Pvt. Bath&Balcony'
#  'Parisian Style Apartment in Heart of Brooklyn']

# %%
#Drop nan values in name column 
df.drop(df.loc[df['NAME'].isnull()].index.tolist(),inplace=True)

# %%
df.host_identity_verified.unique()
# Out:
# array(['unconfirmed', 'verified', nan], dtype=object)

# %%
df.host_identity_verified = df.host_identity_verified.fillna('unconfirmed')

# %%
df.rename(columns={'host name':'host_name'},inplace=True)

# %%
df.host_name=df.host_name.fillna('unkonwn')

# %%
df.rename(columns={'neighbourhood group':'neighbourhood_group'},inplace=True)

# %%
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens', nan,
#        'Staten Island', 'Bronx'], dtype=object)

# %%
#replacing with right spelling
df.neighbourhood_group=df.neighbourhood_group.replace('brookln','Brooklyn')
df.neighbourhood_group=df.neighbourhood_group.replace('manhatan','Manhattan')

# %%
#rows which have null values in neighbourhood column
df.loc[df['neighbourhood_group'].isnull()]
# Out:
#              id                                               NAME  \
# 74      1042206                    HARLEM, NEW YORK WELCOMES YOU!!
# 75      1042759                              BLUE TRIM GUEST HOUSE
# 76      1043311             Charming East Village One Bedroom Flat
# 77      1043863                                     Manhattan Room
# 78      1044415                              Little King of Queens
# 90      1051043                  Cozy Bedroom in Williamsburg 3 BR
# 91      1051595                Sunny room+Pvte office in huge loft
# 92      1052148                Spacious Prospect Heights Apartment
# 148     1083076                                            NYC Zen
# 161     1090256                   Indie-Chic Share In Williamsburg
# 168     1094122                 Parlor Room In Victorian Townhouse
# 196     1109587                        Prime Location in Manhattan
# 241     1134440                           ACCOMMODATIONS GALORE #2
# ...

# %%
#filling nan values by using lat and long with chat gpt
df.at[74,'neighbourhood_group']='Manhattan'
df.at[75,'neighbourhood_group']='Brooklyn'
df.at[76,'neighbourhood_group']='Manhattan'
df.at[77,'neighbourhood_group']='Manhattan'
df.at[78,'neighbourhood_group']='Queens'
df.at[90,'neighbourhood_group']='Brooklyn'
df.at[91,'neighbourhood_group']='Brooklyn'
df.at[92,'neighbourhood_group']='Brooklyn'
df.at[148,'neighbourhood_group']='Manhattan'
df.at[161,'neighbourhood_group']='Brooklyn'
df.at[168,'neighbourhood_group']='Brooklyn'
df.at[196,'neighbourhood_group']='Manhattan'
df.at[241,'neighbourhood_group']='Manhattan'
df.at[249,'neighbourhood_group']='Brooklyn'
df.at[262,'neighbourhood_group']='Bronx'
df.at[287,'neighbourhood_group']='Brooklyn'
df.at[295,'neighbourhood_group']='Manhattan'
df.at[319,'neighbourhood_group']='Brooklyn'
df.at[361,'neighbourhood_group']='Queens'
df.at[384,'neighbourhood_group']='Manhattan'
df.at[415,'neighbourhood_group']='Brooklyn'
df.at[448,'neighbourhood_group']='Brooklyn'
df.at[465,'neighbourhood_group']='Manhattan'
df.at[488,'neighbourhood_group']='Manhattan'
df.at[492,'neighbourhood_group']='Manhattan'
df.at[40383,'neighbourhood_group']='Brooklyn'
df.at[40396,'neighbourhood_group']='Manhattan'

# %%
#Area in city
df.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'East Harlem', 'Murray Hill',
#        'Bedford-Stuyvesant', "Hell's Kitchen", 'Upper West Side',
#        'Chinatown', 'South Slope', 'West Village', 'Williamsburg',
#        'Fort Greene', 'Chelsea', 'Crown Heights', 'Park Slope',
#        'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint',
#        'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'Clinton Hill', 'Washington Heights', 'Upper East Side',
#        'Woodside', 'Brooklyn Heights', 'Prospect Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
#        'Little Italy', 'East Flatbush', 'Tompkinsville', 'Astoria',
# ...

# %%
#rows which have null values in neighbourhood column
df.loc[df['neighbourhood'].isnull()]
# Out:
#           id                                            NAME      host id  \
# 517  1286875             "The Oasis" on Bedford Williamsburg  30603782652
# 547  1303444                       STYLISH EAST VILLAGE FLAT   6825076306
# 553  1306758            Comfortable. Spacious. Private Room.  45534966158
# 575  1318909    2 Bed, 2 Bath Apartment on Central Park West  86633710982
# 589  1326641                           CBG Helps Haiti Rm #3  33952991254
# 613  1339896               Wonderfully inviting East Village  84560895335
# 624  1345971           Stylish Studio with exclusive Terrace  21547822804
# 633  1350942             Lower East Side/Chinatown 1 Bedroom  58408401042
# 643  1356465                        2BR  Apt - 20min to Soho  21192497123
# 670  1371377                Loft Suite @ The Box House Hotel  75427375884
# 678  1375795                Loft Suite @ The Box House Hotel  34416621424
# 681  1377452               Loft w/ Terrace @ Box House Hotel  77372797211
# ...

# %%
#filling nan values by using lat and long with chat gpt
df.at[517,'neighbourhood']='Williamsburg'
df.at[547,'neighbourhood']='East Village'
df.at[553,'neighbourhood']='Chinatown'
df.at[575,'neighbourhood']='Morningside Heights'
df.at[589,'neighbourhood']='Prospect Heights'
df.at[613,'neighbourhood']='East Village'
df.at[624,'neighbourhood']='Turtle Bay'
df.at[633,'neighbourhood']='Lower East Side'
df.at[643,'neighbourhood']='Bedford-Stuyvesant'
df.at[670,'neighbourhood']='Greenpoint'
df.at[678,'neighbourhood']='Greenpoint'
df.at[681,'neighbourhood']='Greenpoint'
df.at[726,'neighbourhood']='Midtown'
df.at[731,'neighbourhood']='Upper West Side'
df.at[760,'neighbourhood']='Williamsburg'
df.at[770,'neighbourhood']='Sunset Park'

# %%
#lat and long null values
df.loc[df['lat'].isnull()]
# Out:
#           id                                   NAME      host id  \
# 779  1431578  Large, furnished room in a 2 bedroom!  20368956893
# 785  1434892      Authentic NY Charming Artist Loft  66486085219
# 799  1442624         Huge room with private balcony  69386945815
# 814  1450908    Decorators 5-Star Flat West Village  33280739304
# 843  1466925     Nice Private Room Beauty in Queens  15305733205
# 885  1490122            Cute Room in Historic Loft!  42267829819
# 926  1512766        21 day Chelsea Apartment rental  10876728736
# 986  1545904         New York City for All Seasons!  26437872336
#
#     host_identity_verified host_name neighbourhood_group      neighbourhood  \
# 779            unconfirmed    Gibson            Brooklyn      Crown Heights
# 785            unconfirmed    Bailey            Brooklyn         Greenpoint
# 799               verified      Hunt           Manhattan       East Village
# ...

# %%
#for filling values in two columns at same time
df.loc[779, ['lat', 'long']] = ['40.6694', '-73.9438']
df.loc[785,['lat','long']] = ['40.7265',' -73.9815']
df.loc[799,['lat','long']] = [' 40.7358','-74.0036']
df.loc[814,['lat','long']] = ['40.7358','-74.0036']
df.loc[843,['lat','long']] = ['40.7425','-73.8780']
df.loc[885,['lat','long']] = ['40.7304','-73.9543']
df.loc[926,['lat','long']] = ['40.7401','-73.9903']
df.loc[986,['lat','long']] = ['40.7860','-73.9754']
# Out:
# C:\Users\sujal\AppData\Local\Temp\ipykernel_13364\1742572120.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40.6694' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[779, ['lat', 'long']] = ['40.6694', '-73.9438']
# C:\Users\sujal\AppData\Local\Temp\ipykernel_13364\1742572120.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-73.9438' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[779, ['lat', 'long']] = ['40.6694', '-73.9438']

# %%
df.country.unique()
# Out:
# array(['United States', nan], dtype=object)

# %%
df.country = df.country.fillna('United States')

# %%
df.rename(columns={'country code':'country_code'},inplace=True)

# %%
df.country_code.unique()
# Out:
# array(['US', nan], dtype=object)

# %%
df.country_code = df.country_code.fillna('US')

# %%
df.instant_bookable.unique()
# Out:
# array([ 0.,  1., nan])

# %%
df.instant_bookable = df.instant_bookable.fillna(0)

# %%
df.loc[df['instant_bookable'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, NAME, host id, host_identity_verified, host_name, neighbourhood_group, neighbourhood, lat, long, country, country_code, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, license]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.cancellation_policy.unique()
# Out:
# array(['strict', 'moderate', 'flexible', nan], dtype=object)

# %%
df.cancellation_policy = df.cancellation_policy.fillna('Not Unkown')

# %%
df.rename(columns={'Construction year':'construction_year'},inplace=True)

# %%
#we will not change nan bcz when we convert in date datatype it will show analysis
df.construction_year.unique()
# Out:
# array([2020., 2007., 2005., 2009., 2013., 2015., 2004., 2008., 2010.,
#        2019., 2018., 2006., 2016., 2017., 2021., 2003., 2011., 2012.,
#        2022., 2014.,   nan])

# %%
#Price column cleaning and data type change
df.price.unique()
df.price = df.price.str.replace('[$,]','',regex=True)
df.price = df.price.fillna('0')
df.price = df.price.astype('int64')

# %%
#service fee
df.rename(columns={'service fee':'service_fee'},inplace=True)
df.service_fee =df.service_fee.str.replace('[$,]','',regex=True)
df.service_fee = df.service_fee.fillna('0')
df.service_fee = df.service_fee.astype('int64')

# %%
df.service_fee.unique()
# Out:
# array([193,  28, 124,  41, 115,  14, 212, 204,  58,  64, 121, 143, 116,
#         30,   0,  56,  95,  27, 210, 163, 235, 106,  55,  42,  86, 133,
#        154, 102, 172, 109,  38, 222, 219, 202, 113,  74, 137, 171,  12,
#         87, 183,  92,  73, 146, 180,  67,  51, 181,  88, 165, 129, 207,
#         17,  63, 147, 105,  48, 114,  80,  23,  11, 149, 213, 211, 182,
#        117,  39,  25, 216,  53,  10, 118,  72, 101,  61, 177,  49, 100,
#        168,  13, 152, 126, 135,  46,  91, 199, 158, 221, 132, 189,  90,
#        186,  66, 225, 220,  19, 238, 119,  98,  34, 227,  32, 148, 203,
#         93, 153,  71,  77, 190,  75, 185,  97,  35,  37, 231,  82, 120,
#         21, 145,  65, 144, 108, 194,  16, 217, 188,  81,  50, 176, 151,
#         26,  89, 218, 104,  44,  79,  22, 131, 240, 192, 215, 191,  94,
#        206, 157, 159, 233,  15, 229, 179,  85, 136, 170, 201, 175, 141,
#        156, 123,  36, 198, 122, 208, 140,  68, 196,  70, 187, 228, 209,
# ...

# %%
#min nights cleaning
df.rename(columns={'minimum nights':'min_nights'},inplace=True)
df.min_nights.unique()
df.min_nights=df.min_nights.replace('[-]','',regex=True)
df.min_nights = df.min_nights.fillna('0')
df.min_nights = df.min_nights.astype('int64')

# %%
#Removing all empty space with underscol
df.columns=df.columns.str.replace(' ','_',regex=True)

# %%
#number of reviews
df.number_of_reviews.unique()
df.number_of_reviews = df.number_of_reviews.fillna('0')
df.number_of_reviews = df.number_of_reviews.astype('int64')

# %%
df.last_review.unique()
# Out:
# array(['10/19/2021', '5/21/2022', nan, ..., '2/26/2020', '2/25/2020',
#        '2/24/2020'], dtype=object)

# %%
#reviews_per_month
df.reviews_per_month.unique()
df.reviews_per_month=df.reviews_per_month.fillna('0')
df.reviews_per_month = df.reviews_per_month.astype('int64')

# %%
#review_rate_number
df.review_rate_number.unique()
df.review_rate_number=df.review_rate_number.fillna('0')

# %%
#calculated_host_listings_count
df.calculated_host_listings_count.unique()
df.calculated_host_listings_count=df.calculated_host_listings_count.fillna('0')
df.calculated_host_listings_count.astype('int64')
# Out:
# 0         6
# 1         2
# 2         1
# 4         1
# 5         1
#          ..
# 102594    1
# 102595    2
# 102596    1
# 102597    1
# 102598    1
# Name: calculated_host_listings_count, Length: 102329, dtype: int64

# %%
#availability_365
df.availability_365.unique()
df.availability_365 = df.availability_365.abs()
df.availability_365=df.availability_365.fillna('0')
df.availability_365.astype('int64')
# Out:
# 0         286
# 1         228
# 2         352
# 4         289
# 5         374
#          ...
# 102594    227
# 102595    395
# 102596    342
# 102597    386
# 102598     69
# Name: availability_365, Length: 102329, dtype: int64

# %%
df.drop(columns=['license'], inplace=True)

# %%
df.house_rules.unique()
df.house_rules=df.house_rules.fillna('no rule')

# %%
df.availability_365 = df.availability_365.astype('int64')
df.calculated_host_listings_count = df.calculated_host_listings_count.astype('int64')
df.review_rate_number = df.review_rate_number.astype('int64')
df.last_review = df.last_review.astype('datetime64[ns]')
df.instant_bookable = df.instant_bookable.astype('int64')

# %%
df.construction_year = df.construction_year.fillna(0).astype('int64')

# %%
df.dtypes
# Out:
# id                                         int64
# NAME                                      object
# host_id                                    int64
# host_identity_verified                    object
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# lat                                       object
# long                                      object
# country                                   object
# country_code                              object
# instant_bookable                           int64
# cancellation_policy                       object
# room_type                                 object
# construction_year                          int64
# price                                      int64
# service_fee                                int64
# min_nights                                 int64
# number_of_reviews                          int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# NAME                                  0
# host_id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# country                               0
# country_code                          0
# instant_bookable                      0
# cancellation_policy                   0
# room_type                             0
# construction_year                     0
# price                                 0
# service_fee                           0
# min_nights                            0
# number_of_reviews                     0
# last_review                       15857
# reviews_per_month                     0
# review_rate_number                    0
# calculated_host_listings_count        0
# ...
